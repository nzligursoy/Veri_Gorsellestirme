# %% [markdown]
# <a href="https://colab.research.google.com/github/nzligursoy/Veri_Gorsellestirme/blob/main/Veri_G%C3%B6rselle%C5%9Ftirme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Line Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# Görselleri görmek için her defasında “plt.show()” satırını yazmayı önlüyor.

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['petal_length'].plot()

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.lineplot(data=iris, y='petal_length', x=iris.index)

# %%
sns.lineplot(data=iris, y='petal_width', x=iris.index, hue='species')

# %% [markdown]
# # 2.Scatter Plot

# %%
fig, ax = plt.subplots() # olası notasyon bu şekildedir.
ax.scatter(iris['sepal_length'], iris['sepal_width'])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# # 3.Bar Plot

# %%
iris.groupby(by='species').mean()['petal_length']
# Out:
# species
# setosa        1.462
# versicolor    4.260
# virginica     5.552
# Name: petal_length, dtype: float64

# %%
data = iris.groupby(by='species').mean()['petal_length']
ax = sns.barplot(x=data.index, y=data.values)
ax.set_title('Petal Length Means')
ax.set_xlabel('Species')
ax.set_ylabel('Mean')
# Out:
# Text(0, 0.5, 'Mean')

# %% [markdown]
# # 4.Histogram

# %%
sns.histplot(data=iris, x='petal_length')

# %%
sns.histplot(data=iris, y='petal_length')

# %%
sns.histplot(data=iris, x='petal_length', hue='species')

# %%
sns.histplot(data=iris, x='petal_length', hue='species', bins=20)

# %% [markdown]
# # 5.Heatmap

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr())

# %%
sns.heatmap(iris.corr(), annot=True)

# %% [markdown]
# # 6.Box Plot

# %%
sns.boxplot(y='sepal_length', x='species', data=iris)
